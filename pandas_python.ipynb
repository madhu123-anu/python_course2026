# %%
! pip install pandas
! pip install numpy
import pandas as pd
import numpy as np

# %%
#series,index,dtype
student=pd.Series(['Madhu','Hari','Lakshmi','Krishna','Ramu'],index=[0,1,2,3,4],dtype=str)
student
# Out:
# 0      Madhu
# 1       Hari
# 2    Lakshmi
# 3    Krishna
# 4       Ramu
# dtype: object

# %%
s2=pd.DataFrame([[1,2,3,4],[2,4,6,7]])
print(s2)
s3=pd.DataFrame([["madhu",200000],["ker",50000],["tabe",3000000]],index=[1,2,3],columns=["name","salary"])
print("\n",s3)
data=[{"madhu":200000},{"keer":500000},{"tabe":6000000}]
s4=pd.DataFrame(data)
print("\n",s4)
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  2  4  6  7
#
#      name   salary
# 1  madhu   200000
# 2    ker    50000
# 3   tabe  3000000
#
#        madhu      keer       tabe
# 0  200000.0       NaN        NaN
# 1       NaN  500000.0        NaN
# 2       NaN       NaN  6000000.0

# %%
print(s3["name"])
print(s3["salary"])
s3["newsalary"]=s3["salary"]+5
print(s3)
# Out:
# 1    madhu
# 2      ker
# 3     tabe
# Name: name, dtype: object
# 1     200000
# 2      50000
# 3    3000000
# Name: salary, dtype: int64
#     name   salary  newsalary
# 1  madhu   200000     200005
# 2    ker    50000      50005
# 3   tabe  3000000    3000005

# %%
marks=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],index=[1,2,3],columns=["math","hin","eng"])
print(marks)
marks['avg']=marks['math']+marks['hin']+marks['eng']/3
print("\n",marks)
print(marks.info())
print(marks.describe())
# Out:
#    math  hin  eng
# 1     1    2    3
# 2     4    5    6
# 3     7    8    9
#
#     math  hin  eng   avg
# 1     1    2    3   4.0
# 2     4    5    6  11.0
# 3     7    8    9  18.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 1 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   math    3 non-null      int64
#  1   hin     3 non-null      int64
#  2   eng     3 non-null      int64
#  3   avg     3 non-null      float64
# dtypes: float64(1), int64(3)
# memory usage: 120.0 bytes
# None
#        math  hin  eng   avg
# count   3.0  3.0  3.0   3.0
# mean    4.0  5.0  6.0  11.0
# std     3.0  3.0  3.0   7.0
# min     1.0  2.0  3.0   4.0
# 25%     2.5  3.5  4.5   7.5
# 50%     4.0  5.0  6.0  11.0
# 75%     5.5  6.5  7.5  14.5
# max     7.0  8.0  9.0  18.0

# %%
employee=pd.DataFrame([[101,"vasanth","2l"],[102,"balu","1l"],[103,"harish","4l"],[104,"leela","6l"]],columns=["id","name","salary"])
print(employee)
print("\n",employee[["id","name"]])
# Out:
#     id     name salary
# 0  101  vasanth     2l
# 1  102     balu     1l
# 2  103   harish     4l
# 3  104    leela     6l
#
#      id     name
# 0  101  vasanth
# 1  102     balu
# 2  103   harish
# 3  104    leela

# %%
employee.pop('name')
print(employee)
# Out:
#     id salary
# 0  101     2l
# 1  102     1l
# 2  103     4l
# 3  104     6l

# %%
del marks['math']
print(marks)
marks.insert(1,'tel',[1,4,7])
print("\n",marks)
# Out:
#    hin  eng   avg
# 1    2    3   4.0
# 2    5    6  11.0
# 3    8    9  18.0
#
#     hin  tel  eng   avg
# 1    2    1    3   4.0
# 2    5    4    6  11.0
# 3    8    7    9  18.0

# %%
seq=pd.DataFrame({"colm1":np.random.randint(2,11,size=(20)),"colm2":np.random.randint(1,10,size=(20))})
print(seq)
print(seq.head())
print(seq.tail())
# Out:
#     colm1  colm2
# 0       2      1
# 1       9      3
# 2       2      1
# 3       4      6
# 4       7      4
# 5       2      6
# 6      10      5
# 7       9      5
# 8       5      5
# 9       8      8
# 10      9      2
# 11      2      7
# 12      5      2
# 13      9      4
# 14     10      9
# 15      2      5
# 16      6      4
# 17      7      8
# 18      8      7
# 19      6      2
#    colm1  colm2
# 0      2      1
# 1      9      3
# 2      2      1
# 3      4      6
# 4      7      4
#     colm1  colm2
# 15      2      5
# 16      6      4
# 17      7      8
# 18      8      7
# 19      6      2
